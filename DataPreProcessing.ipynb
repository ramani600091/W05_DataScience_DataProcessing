# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv('heart.csv')

# %%
dataset
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289        0.0     Normal
# 1     49   F           NAP        160          180        0.0     Normal
# 2     37   M           ATA        130          283        0.0         ST
# 3     48   F           ASY        138          214        0.0     Normal
# 4     54   M           NAP        150          195        0.0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264        0.0     Normal
# 914   68   M           ASY        144          193        1.0     Normal
# 915   57   M           ASY        130          131        0.0     Normal
# 916   57   F           ATA        130          236        0.0        LVH
# 917   38   M           NAP        138          175        0.0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      NaN       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      NaN       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      NaN       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      NaN     Flat             1
# 917    173              N      NaN       Up             0
#
# [918 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# Age                 0
# Sex                 0
# ChestPainType       0
# RestingBP           0
# Cholesterol         0
# FastingBS          14
# RestingECG          0
# MaxHR               0
# ExerciseAngina      0
# Oldpeak           368
# ST_Slope            0
# HeartDisease        0
# dtype: int64

# %%
dataset["Oldpeak"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289        0.0     Normal
# 1     49   F           NAP        160          180        0.0     Normal
# 2     37   M           ATA        130          283        0.0         ST
# 3     48   F           ASY        138          214        0.0     Normal
# 4     54   M           NAP        150          195        0.0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264        0.0     Normal
# 914   68   M           ASY        144          193        1.0     Normal
# 915   57   M           ASY        130          131        0.0     Normal
# 916   57   F           ATA        130          236        0.0        LVH
# 917   38   M           NAP        138          175        0.0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
dataset.isna().sum()
# Out:
# Age                0
# Sex                0
# ChestPainType      0
# RestingBP          0
# Cholesterol        0
# FastingBS         14
# RestingECG         0
# MaxHR              0
# ExerciseAngina     0
# Oldpeak            0
# ST_Slope           0
# HeartDisease       0
# dtype: int64

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual= quanQual(dataset)

# %%
#Still "NaN" values found in another coloumn "FastingBS".

# %%
#We can proceed wiht another method of replacing the "NaN" columns in every columns in the table in one execution

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])
df = pd.DataFrame(df,columns = quan)

# %%
imp
# Out:
# SimpleImputer()

# %%
df
# Out:
#       Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0    40.0      140.0        289.0        0.0  172.0      0.0           0.0
# 1    49.0      160.0        180.0        0.0  156.0      1.0           1.0
# 2    37.0      130.0        283.0        0.0   98.0      0.0           0.0
# 3    48.0      138.0        214.0        0.0  108.0      1.5           1.0
# 4    54.0      150.0        195.0        0.0  122.0      0.0           0.0
# ..    ...        ...          ...        ...    ...      ...           ...
# 913  45.0      110.0        264.0        0.0  132.0      1.2           1.0
# 914  68.0      144.0        193.0        1.0  141.0      3.4           1.0
# 915  57.0      130.0        131.0        0.0  115.0      1.2           1.0
# 916  57.0      130.0        236.0        0.0  174.0      0.0           1.0
# 917  38.0      138.0        175.0        0.0  173.0      0.0           0.0
#
# [918 rows x 7 columns]
